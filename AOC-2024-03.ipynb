# %%
# !vimr 2024-12-03.txt

# %%
from collections import Counter
import numpy as np
from pathlib import Path

data_real = Path('2024-12-03.txt').read_text()

data_test = """xmul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))
"""
data_test = """xmul(2,4)&mul[3,7]!^don't()_mul(5,5)+mul(32,64](mul(11,8)undo()?mul(8,5))
"""

data = data_test.splitlines()
#data= data_real.splitlines()
acc = 0
import re
for line in data:
    groups = re.findall(r'mul\(\d+,\d+\)', line)
    for g in groups:
        
        a,b = g[4:-1].split(',')
        acc += int(a)*int(b)

# %%
acc
# Out:
# 196826776

# %%
data = data_test.splitlines()
data= data_real.splitlines()
acc = 0
mul = 1
import re
for line in data:
    groups = re.findall(r'mul\(\d+,\d+\)|do\(\)|don\'t\(\)', line)
    for g in groups:
        print(mul, g)
        if g == 'do()':
            
            mul=1
            continue
        elif  g == "don't()":
            mul=0
            continue
        a,b = g[4:-1].split(',')
        #print(a,b,mul)
        acc += int(a)*int(b)*mul
acc
# Out:
# 1 mul(241,173)
# 1 mul(978,869)
# 1 mul(768,14)
# 1 mul(919,141)
# 1 mul(917,743)
# 1 mul(480,547)
# 1 mul(787,859)
# 1 mul(831,935)
# 1 mul(412,254)
# 1 mul(882,793)
# 1 mul(576,815)
# 1 mul(872,894)
# 1 mul(893,419)
# 1 mul(777,637)
# 1 mul(976,384)
# 1 mul(152,26)
# 1 mul(345,409)
# 1 mul(520,140)
# 1 mul(587,697)
# 1 mul(724,433)
# 1 mul(616,904)
# 1 mul(314,689)
# 1 mul(977,452)
# 1 mul(915,188)
# 1 mul(75,280)
# 1 mul(496,507)
# 1 mul(334,91)
# 1 mul(674,796)
# 1 mul(974,568)
# 1 mul(699,339)
# 1 mul(136,788)
# 1 don't()
# 0 mul(820,911)
# 0 mul(505,633)
# 0 mul(739,984)
# 0 mul(560,40)
# 0 mul(745,527)
# 0 mul(238,266)
# 0 mul(350,760)
# 0 don't()
# 0 mul(591,538)
# 0 mul(567,522)
# 0 mul(584,847)
# 0 mul(610,82)
# 0 mul(710,144)
# 0 mul(834,874)
# 0 mul(574,485)
# 0 mul(33,399)
# 0 mul(547,850)
# 0 mul(321,474)
# 0 mul(265,718)
# 0 mul(199,69)
# 0 mul(779,529)
# 0 mul(974,547)
# 0 mul(822,46)
# 0 mul(246,341)
# 0 mul(685,763)
# 0 mul(556,47)
# 0 mul(827,911)
# 0 do()
# ...
